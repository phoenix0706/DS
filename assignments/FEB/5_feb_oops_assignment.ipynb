# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **ANS 1**
# Class: A class is a blueprint or template for creating objects. It defines properies (attributes) and behaviours (methods) that the objects created from it will have.
# A class provides a way to encapsulate data and functionality into single unit

# %%
class Car:
    def __init__(self, make, model):
        self.make = make
        self.model = model

    def start_engine(self):
        print(f"The {self.make} {self.model}'s engine is running.")

# Creating objects (instances) of the Car class
car1 = Car("Toyota", "Camry")
car2 = Car("Honda", "Civic")

car1.start_engine()  # Output: The Toyota Camry's engine is running.
car2.start_engine()  # Output: The Honda Civic's engine is running.
# Out:
# The Toyota Camry's engine is running.
# The Honda Civic's engine is running.

# %% [markdown]
# Object: An object is an instance of a class. It represents a real world entity and has attributes (data) and methods( functions) associated with it, as defined in the class

# %% [markdown]
# **ANS 2**
#
# The four pillars of Object-Oriented Programming (OOPs) are:
#
#
# 1. Encapsulation: Encapsulation involves bundling data (attributes ) and methods(functions) that operate on the data into a single unit i.e. class. It restricts direct access to the data and promotes data protection
#
# 2. Abstraction: Abstraction focuses on providing essential features while hiding unnecessary details. It allows you to work with high level concepts and hide the complexities.
#
# 3. Inheritance: Inheritance enables the creation of new classes (derived or child classes ) based on existing classes (base or parent classes). It promotes code reuse and supports the "is-a" relationship.
#
# 4. Polymorphism: Polymorphism allows objects of different classes as objects of a common base class. It involves method overriding and method overloading, enabling flexibility and dynamic behaviour in the program

# %% [markdown]
# **ANS 3**
#
#
#
# The '_ __init__ __()' function is used as the constructor method in a class. It is automatically called when an object is created from the class. The purpose of the '_ ___init__ _()' function is to initialise the attributes of the object.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person1 = Person("Alice", 25)
person2 = Person("Bob", 30)

person1.greet()  # Output: Hello, my name is Alice and I am 25 years old.
person2.greet()  # Output: Hello, my name is Bob and I am 30 years old.
# Out:
# Hello, my name is Alice and I am 25 years old.
# Hello, my name is Bob and I am 30 years old.

# %% [markdown]
# **ANS 4**
#
# In  object-oriented programming (OOP), 'self' is used as a reference to the instance of the class. It represents the current object that is being operated in.
# When methods are called on the object, the 'self' parameter allows those methods to access and manipulate the object's attributes.
#
# For example, within a method of a class, you can use self.attribute_name to access and modify the object's attributes. It's a way for methods to communicate and interact with the object's data.

# %% [markdown]
# **ANS 5**
#
# Inheritance is a fundamental concept in object-oriented programming where a new class (derived or child class) inherits properties and behaviors (attributes and methods) from an existing class (base or parent class). This promotes code reuse and establishes a "is-a" relationship between the classes.
#
# There are different types of inheritance:
#
# Single Inheritance: A derived class inherits from a single base class.
# Multiple Inheritance: A derived class inherits from multiple base classes.
# Multilevel Inheritance: A chain of inheritance where a class is derived from another class, and that class is further derived from another class.
# Hierarchical Inheritance: Multiple classes are derived from a single base class.
# Hybrid Inheritance: A combination of two or more types of inheritance.

# %%
#Single Inheritance example
class Animal:
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        print("Woof!")

class Cat(Animal):
    def speak(self):
        print("Meow!")

dog = Dog()
cat = Cat()

dog.speak()  # Output: Woof!
cat.speak()  # Output: Meow!
# Out:
# Woof!
# Meow!

# %%
# Multiple INheritance Example

class Flyer:
    def fly(self):
        pass

class Swimmer:
    def swim(self):
        pass

class Bird(Flyer):
    def fly(self):
        print("Bird can fly.")

class Fish(Swimmer):
    def swim(self):
        print("Fish can swim.")

class Duck(Bird, Swimmer):
    pass

duck = Duck()
duck.fly()   # Output: Bird can fly.
duck.swim()  # Output: Fish can swim.
# Out:
# Bird can fly.
