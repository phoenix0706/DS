# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ans1: Guido van Rossum developed Python programming language.

# %% [markdown]
# Ans2: Python supports procedural, object oriented and functional programming.

# %% [markdown]
# Ans3: Yes python is case sensitive when dealing with identifiers.

# %% [markdown]
# Ans4: ".py" is correct extension of python file.

# %% [markdown]
# Ans5: Python code is interpreted.

# %% [markdown]
# Ans6: Module, a function body and a class definition are a few blocks of code used to define in python language.

# %% [markdown]
# Ans7: "#" (hash) is used to give single line comments in python

# %% [markdown]
# Ans8: Functions which can help find python versiona re sys.version by importing sys module and python_version() by importing python_version from platform module.

# %%
from platform import python_version
print(python_version())
# Out:
# 3.10.4

# %%
import sys
print(sys.version)
# Out:
# 3.10.4 (tags/v3.10.4:9d38120, Mar 23 2022, 23:13:41) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# Ans9: Python supports the creationof anonymous functions at runtime, using a construct called **lambda**
# function.

# %% [markdown]
# Ans10: PIP stands for "Pip Installs Packages" and is a package management system used to install and manage software packages written in Python.

# %% [markdown]
# Ans11: Few built in function in python are chr(), ord(), abs(),all(), bin(), bool() etc.

# %% [markdown]
# Ans12: An identifier can have a maximum length of 79 characters in Python.

# %% [markdown]
# Ans13:Benefits of using Python are:
# 1. It is easy to read, learn and write.
# 2. It is free and open source.
# 3. It has a wide field of applications such as datascience, web development, gaming etc.
# 4. It supports object oriented programming
# 5. Python includes a huge number of libraries that the user can use.

# %% [markdown]
# Ans14: Memory management in Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager.

# %% [markdown]
# Ans15:
# 1. Go to the official Python download page for Windows.
#
# 2. Find a stable Python 3 release. This tutorial was tested with Python version 3.10.10.
#
# 3. Click the appropriate link for your system to download the executable file: Windows installer (64-bit) or Windows installer (32-bit).
#
# 4. After the installer is downloaded, double-click the .exe file, for example python-3.10.10-amd64.exe, to run the Python installer.
#
# 5. Select the Install launcher for all users checkbox, which enables all users of the computer to access the Python launcher application.
#
# 6. Select the Add python.exe to PATH checkbox, which enables users to launch Python from the command line.

# %% [markdown]
# Ans16: Yes indentation is required in Python.
